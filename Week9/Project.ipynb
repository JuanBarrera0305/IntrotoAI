# %%
import random
import math
from typing import List, Dict, Tuple

random.seed(42)

LANES = 8
LANE_PATTERN = [4, 5, 3, 6, 2, 7, 1, 8]  # assignment order for ranks 1..8

# --- Data structures ---
class Athlete:
    def __init__(self, athlete_id: int, name: str, seed_time: float):
        self.id = athlete_id
        self.name = name
        self.seed_time = seed_time

class Assignment:
    def __init__(self, round_name: str, heat_index: int, lane: int, athlete: Athlete):
        self.round = round_name
        self.heat_index = heat_index
        self.lane = lane
        self.athlete = athlete

class Result:
    def __init__(self, assignment: Assignment, time: float):
        self.assignment = assignment
        self.time = time

# --- Helpers ---
def generate_athletes(n: int) -> List[Athlete]:
    # Create athletes with seed times centered around 10.80 ± 0.60s
    athletes = []
    for i in range(n):
        base = 10.8 + random.gauss(0, 0.6)
        seed = max(9.8, min(12.5, base))  # clamp to reasonable sprint times
        athletes.append(Athlete(i+1, f"Athlete_{i+1}", round(seed, 3)))
    # Sort by seed time ascending (fastest first)
    athletes.sort(key=lambda a: a.seed_time)
    return athletes

def serpentine_groups(athletes: List[Athlete], lanes: int) -> List[List[Athlete]]:
    # Group athletes into heats of 'lanes' using serpentine distribution
    n = len(athletes)
    heats = math.ceil(n / lanes)
    groups = [[] for _ in range(heats)]
    idx = 0
    direction = 1  # 1 forward, -1 backward
    while idx < n:
        # fill a "row" across heats
        if direction == 1:
            for h in range(heats):
                if idx < n:
                    groups[h].append(athletes[idx])
                    idx += 1
            direction = -1
        else:
            for h in reversed(range(heats)):
                if idx < n:
                    groups[h].append(athletes[idx])
                    idx += 1
            direction = 1
    # Ensure each group length <= lanes
    for g in groups:
        if len(g) > lanes:
            raise ValueError("Group overflow; check serpentine logic.")
    return groups

def assign_lanes(group: List[Athlete], round_name: str, heat_index: int) -> List[Assignment]:
    # Assign lanes according to LANE_PATTERN for ranks within the heat
    # Rank group by seed_time ascending (fastest first)
    ranked = sorted(group, key=lambda a: a.seed_time)
    assignments = []
    for i, athlete in enumerate(ranked):
        lane = LANE_PATTERN[i] if i < len(LANE_PATTERN) else None
        assignments.append(Assignment(round_name, heat_index, lane, athlete))
    return assignments

def simulate_heat_results(assignments: List[Assignment]) -> List[Result]:
    # Simulate performance around seed_time with Gaussian noise
    results = []
    for a in assignments:
        noise = random.gauss(0, 0.08)  # 80ms std dev
        time = max(9.6, a.athlete.seed_time + noise)
        results.append(Result(a, round(time, 3)))
    # Sort by time ascending within heat
    results.sort(key=lambda r: r.time)
    return results

def progress_next_round(all_heat_results: List[List[Result]], auto_slots: int, target_size: int) -> List[Athlete]:
    # Auto-qualify winners of each heat
    winners = [heat_res[0].assignment.athlete for heat_res in all_heat_results]
    # Collect remaining athletes + times across all heats
    remaining = []
    for heat_res in all_heat_results:
        for r in heat_res[1:]:
            remaining.append((r.assignment.athlete, r.time))
    # Sort remaining by time ascending
    remaining.sort(key=lambda x: x[1])
    # Fill remaining slots to reach target_size
    need = target_size - len(winners)
    qualifiers = winners + [ath for ath, _ in remaining[:need]]
    # De-duplicate and ensure size
    unique = []
    seen = set()
    for a in qualifiers:
        if a.id not in seen:
            unique.append(a)
            seen.add(a.id)
    if len(unique) != target_size:
        raise ValueError("Progression size mismatch; check inputs and rule.")
    return unique

def round_assignments(athletes: List[Athlete], round_name: str) -> Tuple[List[List[Assignment]], List[List[Result]]]:
    groups = serpentine_groups(athletes, LANES)
    all_assignments = []
    all_results = []
    for h_idx, group in enumerate(groups, start=1):
        assigns = assign_lanes(group, round_name, h_idx)
        results = simulate_heat_results(assigns)
        all_assignments.append(assigns)
        all_results.append(results)
    return all_assignments, all_results

def print_round(all_assignments: List[List[Assignment]], all_results: List[List[Result]]):
    for h_idx, (assigns, results) in enumerate(zip(all_assignments, all_results), start=1):
        print(f"Round {assigns[0].round} — Heat {h_idx}")
        print("  Assignments (seed_time):")
        for a in sorted(assigns, key=lambda x: x.lane):
            print(f"    Lane {a.lane}: {a.athlete.name} ({a.athlete.seed_time}s)")
        print("  Results (simulated times):")
        for place, r in enumerate(results, start=1):
            print(f"    {place}. {r.assignment.athlete.name} — {r.time}s (Lane {r.assignment.lane})")
        print()

# --- Meet pipeline for 80 athletes on 8 lanes ---
def run_meet():
    athletes = generate_athletes(80)

    # Round 1: Heats (10 heats of 8 lanes)
    R1_assigns, R1_results = round_assignments(athletes, "Heats")
    print_round(R1_assigns, R1_results)

    # Progress to Semifinals: target 24 athletes
    semifinalists = progress_next_round(R1_results, auto_slots=len(R1_results), target_size=24)

    # Round 2: Semifinals (3 heats of 8 lanes)
    R2_assigns, R2_results = round_assignments(semifinalists, "Semifinals")
    print_round(R2_assigns, R2_results)

    # Progress to Final: target 8 athletes
    finalists = progress_next_round(R2_results, auto_slots=len(R2_results), target_size=8)

    # Round 3: Final (1 heat of 8 lanes)
    R3_assigns, R3_results = round_assignments(finalists, "Final")
    print_round(R3_assigns, R3_results)

if __name__ == "__main__":
    run_meet()
# Out:
# Round Heats — Heat 1
#   Assignments (seed_time):
#     Lane 1: Athlete_13 (11.194s)
#     Lane 2: Athlete_14 (10.866s)
#     Lane 3: Athlete_75 (10.463s)
#     Lane 4: Athlete_33 (9.8s)
#     Lane 5: Athlete_78 (10.46s)
#     Lane 6: Athlete_19 (10.825s)
#     Lane 7: Athlete_47 (11.19s)
#     Lane 8: Athlete_54 (12.201s)
#   Results (simulated times):
#     1. Athlete_33 — 9.742s (Lane 4)
#     2. Athlete_75 — 10.316s (Lane 3)
#     3. Athlete_78 — 10.437s (Lane 5)
#     4. Athlete_19 — 10.738s (Lane 6)
#     5. Athlete_14 — 10.821s (Lane 2)
#     6. Athlete_47 — 11.223s (Lane 7)
#     7. Athlete_13 — 11.289s (Lane 1)
#     8. Athlete_54 — 12.2s (Lane 8)
#
# Round Heats — Heat 2
#   Assignments (seed_time):
#     Lane 1: Athlete_37 (11.199s)
#     Lane 2: Athlete_43 (10.869s)
#     Lane 3: Athlete_64 (10.481s)
#     Lane 4: Athlete_32 (9.891s)
#     Lane 5: Athlete_34 (10.436s)
#     Lane 6: Athlete_67 (10.82s)
#     Lane 7: Athlete_45 (11.183s)
#     Lane 8: Athlete_72 (12.193s)
#   Results (simulated times):
#     1. Athlete_32 — 9.912s (Lane 4)
#     2. Athlete_34 — 10.449s (Lane 5)
#     3. Athlete_64 — 10.568s (Lane 3)
#     4. Athlete_67 — 10.891s (Lane 6)
#     5. Athlete_43 — 10.891s (Lane 2)
#     6. Athlete_45 — 11.102s (Lane 7)
#     7. Athlete_37 — 11.271s (Lane 1)
#     8. Athlete_72 — 12.223s (Lane 8)
#
# Round Heats — Heat 3
#   Assignments (seed_time):
#     Lane 1: Athlete_4 (11.221s)
#     Lane 2: Athlete_10 (10.87s)
#     Lane 3: Athlete_51 (10.518s)
#     Lane 4: Athlete_6 (9.902s)
#     Lane 5: Athlete_74 (10.434s)
#     Lane 6: Athlete_79 (10.758s)
#     Lane 7: Athlete_73 (11.172s)
#     Lane 8: Athlete_61 (11.656s)
#   Results (simulated times):
#     1. Athlete_6 — 10.0s (Lane 4)
#     2. Athlete_74 — 10.432s (Lane 5)
#     3. Athlete_51 — 10.674s (Lane 3)
#     4. Athlete_79 — 10.729s (Lane 6)
#     5. Athlete_10 — 10.997s (Lane 2)
#     6. Athlete_4 — 11.18s (Lane 1)
#     7. Athlete_73 — 11.181s (Lane 7)
#     8. Athlete_61 — 11.566s (Lane 8)
#
# Round Heats — Heat 4
#   Assignments (seed_time):
#     Lane 1: Athlete_70 (11.234s)
#     Lane 2: Athlete_11 (10.939s)
#     Lane 3: Athlete_69 (10.611s)
#     Lane 4: Athlete_22 (9.928s)
#     Lane 5: Athlete_49 (10.424s)
#     Lane 6: Athlete_41 (10.748s)
#     Lane 7: Athlete_71 (11.148s)
#     Lane 8: Athlete_58 (11.653s)
#   Results (simulated times):
#     1. Athlete_22 — 9.916s (Lane 4)
#     2. Athlete_49 — 10.538s (Lane 5)
#     3. Athlete_69 — 10.676s (Lane 3)
#     4. Athlete_11 — 10.749s (Lane 2)
#     5. Athlete_41 — 10.803s (Lane 6)
#     6. Athlete_71 — 11.205s (Lane 7)
#     7. Athlete_70 — 11.278s (Lane 1)
#     8. Athlete_58 — 11.609s (Lane 8)
#
# Round Heats — Heat 5
#   Assignments (seed_time):
#     Lane 1: Athlete_80 (11.25s)
#     Lane 2: Athlete_17 (10.948s)
#     Lane 3: Athlete_23 (10.613s)
#     Lane 4: Athlete_66 (9.934s)
#     Lane 5: Athlete_50 (10.37s)
#     Lane 6: Athlete_62 (10.744s)
#     Lane 7: Athlete_31 (11.141s)
#     Lane 8: Athlete_18 (11.587s)
#   Results (simulated times):
#     1. Athlete_66 — 9.884s (Lane 4)
#     2. Athlete_50 — 10.37s (Lane 5)
#     3. Athlete_62 — 10.66s (Lane 6)
#     4. Athlete_23 — 10.751s (Lane 3)
#     5. Athlete_17 — 10.914s (Lane 2)
#     6. Athlete_80 — 11.214s (Lane 1)
#     7. Athlete_31 — 11.25s (Lane 7)
#     8. Athlete_18 — 11.558s (Lane 8)
#
# Round Heats — Heat 6
#   Assignments (seed_time):
#     Lane 1: Athlete_57 (11.261s)
#     Lane 2: Athlete_28 (10.949s)
#     Lane 3: Athlete_42 (10.624s)
#     Lane 4: Athlete_63 (9.946s)
#     Lane 5: Athlete_15 (10.357s)
#     Lane 6: Athlete_20 (10.736s)
#     Lane 7: Athlete_21 (11.119s)
#     Lane 8: Athlete_12 (11.498s)
#   Results (simulated times):
#     1. Athlete_63 — 9.954s (Lane 4)
#     2. Athlete_15 — 10.258s (Lane 5)
#     3. Athlete_20 — 10.639s (Lane 6)
#     4. Athlete_42 — 10.642s (Lane 3)
#     5. Athlete_28 — 11.02s (Lane 2)
#     6. Athlete_21 — 11.119s (Lane 7)
#     7. Athlete_57 — 11.444s (Lane 1)
#     8. Athlete_12 — 11.52s (Lane 8)
#
# Round Heats — Heat 7
#   Assignments (seed_time):
#     Lane 1: Athlete_29 (11.269s)
#     Lane 2: Athlete_68 (10.952s)
#     Lane 3: Athlete_8 (10.64s)
#     Lane 4: Athlete_38 (10.069s)
#     Lane 5: Athlete_55 (10.308s)
#     Lane 6: Athlete_3 (10.733s)
#     Lane 7: Athlete_59 (11.103s)
#     Lane 8: Athlete_65 (11.372s)
#   Results (simulated times):
#     1. Athlete_38 — 10.178s (Lane 4)
#     2. Athlete_55 — 10.204s (Lane 5)
#     3. Athlete_8 — 10.63s (Lane 3)
#     4. Athlete_3 — 10.759s (Lane 6)
#     5. Athlete_59 — 10.969s (Lane 7)
#     6. Athlete_68 — 11.092s (Lane 2)
#     7. Athlete_29 — 11.348s (Lane 1)
#     8. Athlete_65 — 11.419s (Lane 8)
#
# Round Heats — Heat 8
#   Assignments (seed_time):
#     Lane 1: Athlete_44 (11.291s)
#     Lane 2: Athlete_7 (10.999s)
#     Lane 3: Athlete_53 (10.65s)
#     Lane 4: Athlete_30 (10.132s)
#     Lane 5: Athlete_76 (10.301s)
#     Lane 6: Athlete_5 (10.723s)
#     Lane 7: Athlete_52 (11.1s)
#     Lane 8: Athlete_77 (11.371s)
#   Results (simulated times):
#     1. Athlete_30 — 10.255s (Lane 4)
#     2. Athlete_76 — 10.358s (Lane 5)
#     3. Athlete_53 — 10.654s (Lane 3)
#     4. Athlete_5 — 10.681s (Lane 6)
#     5. Athlete_7 — 10.899s (Lane 2)
#     6. Athlete_52 — 11.116s (Lane 7)
#     7. Athlete_44 — 11.276s (Lane 1)
#     8. Athlete_77 — 11.533s (Lane 8)
#
# Round Heats — Heat 9
#   Assignments (seed_time):
#     Lane 1: Athlete_60 (11.301s)
#     Lane 2: Athlete_46 (11.01s)
#     Lane 3: Athlete_26 (10.656s)
#     Lane 4: Athlete_56 (10.141s)
#     Lane 5: Athlete_35 (10.251s)
#     Lane 6: Athlete_1 (10.714s)
#     Lane 7: Athlete_24 (11.094s)
#     Lane 8: Athlete_36 (11.326s)
#   Results (simulated times):
#     1. Athlete_56 — 10.092s (Lane 4)
#     2. Athlete_35 — 10.277s (Lane 5)
#     3. Athlete_26 — 10.53s (Lane 3)
#     4. Athlete_1 — 10.682s (Lane 6)
#     5. Athlete_46 — 11.031s (Lane 2)
#     6. Athlete_24 — 11.16s (Lane 7)
#     7. Athlete_36 — 11.322s (Lane 8)
#     8. Athlete_60 — 11.417s (Lane 1)
#
# Round Heats — Heat 10
#   Assignments (seed_time):
#     Lane 1: Athlete_39 (11.308s)
#     Lane 2: Athlete_27 (11.026s)
#     Lane 3: Athlete_9 (10.67s)
#     Lane 4: Athlete_16 (10.191s)
#     Lane 5: Athlete_40 (10.199s)
#     Lane 6: Athlete_2 (10.696s)
#     Lane 7: Athlete_48 (11.087s)
#     Lane 8: Athlete_25 (11.324s)
#   Results (simulated times):
#     1. Athlete_16 — 10.102s (Lane 4)
#     2. Athlete_40 — 10.236s (Lane 5)
#     3. Athlete_9 — 10.711s (Lane 3)
#     4. Athlete_2 — 10.735s (Lane 6)
#     5. Athlete_27 — 10.97s (Lane 2)
#     6. Athlete_48 — 11.178s (Lane 7)
#     7. Athlete_39 — 11.315s (Lane 1)
#     8. Athlete_25 — 11.38s (Lane 8)
#
# Round Semifinals — Heat 1
#   Assignments (seed_time):
#     Lane 1: Athlete_78 (10.46s)
#     Lane 2: Athlete_15 (10.357s)
#     Lane 3: Athlete_38 (10.069s)
#     Lane 4: Athlete_33 (9.8s)
#     Lane 5: Athlete_63 (9.946s)
#     Lane 6: Athlete_40 (10.199s)
#     Lane 7: Athlete_74 (10.434s)
#     Lane 8: Athlete_8 (10.64s)
#   Results (simulated times):
#     1. Athlete_33 — 9.902s (Lane 4)
#     2. Athlete_63 — 9.995s (Lane 5)
#     3. Athlete_38 — 10.092s (Lane 3)
#     4. Athlete_40 — 10.371s (Lane 6)
#     5. Athlete_15 — 10.376s (Lane 2)
#     6. Athlete_74 — 10.41s (Lane 7)
#     7. Athlete_78 — 10.469s (Lane 1)
#     8. Athlete_8 — 10.759s (Lane 8)
#
# Round Semifinals — Heat 2
#   Assignments (seed_time):
#     Lane 1: Athlete_34 (10.436s)
#     Lane 2: Athlete_55 (10.308s)
#     Lane 3: Athlete_30 (10.132s)
#     Lane 4: Athlete_32 (9.891s)
#     Lane 5: Athlete_66 (9.934s)
#     Lane 6: Athlete_35 (10.251s)
#     Lane 7: Athlete_50 (10.37s)
#     Lane 8: Athlete_64 (10.481s)
#   Results (simulated times):
#     1. Athlete_32 — 9.9s (Lane 4)
#     2. Athlete_66 — 9.976s (Lane 5)
#     3. Athlete_55 — 10.17s (Lane 2)
#     4. Athlete_35 — 10.21s (Lane 6)
#     5. Athlete_30 — 10.228s (Lane 3)
#     6. Athlete_50 — 10.394s (Lane 7)
#     7. Athlete_64 — 10.432s (Lane 8)
#     8. Athlete_34 — 10.454s (Lane 1)
#
# Round Semifinals — Heat 3
#   Assignments (seed_time):
#     Lane 1: Athlete_75 (10.463s)
#     Lane 2: Athlete_76 (10.301s)
#     Lane 3: Athlete_56 (10.141s)
#     Lane 4: Athlete_6 (9.902s)
#     Lane 5: Athlete_22 (9.928s)
#     Lane 6: Athlete_16 (10.191s)
#     Lane 7: Athlete_49 (10.424s)
#     Lane 8: Athlete_26 (10.656s)
#   Results (simulated times):
#     1. Athlete_6 — 9.972s (Lane 4)
#     2. Athlete_22 — 9.977s (Lane 5)
#     3. Athlete_56 — 10.061s (Lane 3)
#     4. Athlete_16 — 10.232s (Lane 6)
#     5. Athlete_76 — 10.285s (Lane 2)
#     6. Athlete_49 — 10.305s (Lane 7)
#     7. Athlete_75 — 10.499s (Lane 1)
#     8. Athlete_26 — 10.652s (Lane 8)
#
# Round Final — Heat 1
#   Assignments (seed_time):
#     Lane 1: Athlete_38 (10.069s)
#     Lane 2: Athlete_66 (9.934s)
#     Lane 3: Athlete_6 (9.902s)
#     Lane 4: Athlete_33 (9.8s)
#     Lane 5: Athlete_32 (9.891s)
#     Lane 6: Athlete_22 (9.928s)
#     Lane 7: Athlete_63 (9.946s)
#     Lane 8: Athlete_56 (10.141s)
#   Results (simulated times):
#     1. Athlete_33 — 9.74s (Lane 4)
#     2. Athlete_22 — 9.882s (Lane 6)
#     3. Athlete_32 — 9.933s (Lane 5)
#     4. Athlete_6 — 9.941s (Lane 3)
#     5. Athlete_66 — 9.966s (Lane 2)
#     6. Athlete_38 — 10.012s (Lane 1)
#     7. Athlete_63 — 10.027s (Lane 7)
#     8. Athlete_56 — 10.171s (Lane 8)
